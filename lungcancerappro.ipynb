# %% [markdown]
# <a href="https://colab.research.google.com/github/swetha-venkatesan/lung-cancer-prediction/blob/main/lungcancerappro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
lung = pd.read_csv(r'/content/survey_lung_cancer.csv')
# lung.head()

# %%
lung
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                1.0         2         1       2.0                  2
# ...

# %%
lung.shape
# Out:
# (309, 16)

# %%
lung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        307 non-null    float64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               308 non-null    float64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               308 non-null    float64
#  12  SHORTNESS OF BREATH    307 non-null    float64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
# ...

# %%
lung.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          2
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 1
# ALCOHOL CONSUMING        0
# COUGHING                 1
# SHORTNESS OF BREATH      2
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
lung.fillna(method='bfill',inplace=True)

# %%
lung.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
print(lung.to_string())
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0        M   69        1               2        2              1              1.0         2         1       2.0                  2       2.0                  2.0                      2           2         YES
# 1        M   74        2               1        1              1              2.0         2         2       1.0                  1       1.0                  2.0                      2           2         YES
# 2        F   59        1               1        1              2              1.0         2         1       2.0                  1       2.0                  2.0                      1           2          NO
# ...

# %%
lung.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0              1.0         2         1       2.0                  2       2.0
# 1              2.0         2         2       1.0                  1       1.0
# 2              1.0         2         1       2.0                  1       2.0
# 3              1.0         1         1       1.0                  2       1.0
# 4              1.0         1         1       2.0                  1       2.0
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
lung.tail()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 304              2.0         2         1       1.0                  2
# 305              1.0         2         2       2.0                  2
# 306              1.0         1         2       2.0                  2
# 307              1.0         2         2       1.0                  2
# 308              1.0         2         2       2.0                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 304       2.0                  2.0                      2           1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
lung['GENDER'] = labelencoder.fit_transform(lung['GENDER'])
# To see the unique encoded values
print(lung['GENDER'].unique())
# Out:
# [1 0]

# %%
x=lung[['GENDER','AGE','SMOKING','YELLOW_FINGERS','ANXIETY','PEER_PRESSURE','CHRONIC DISEASE','WHEEZING','ALCOHOL CONSUMING','COUGHING','SHORTNESS OF BREATH','SWALLOWING DIFFICULTY','CHEST PAIN']]
x
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1.0       2.0                  2       2.0
# ...

# %%
y=lung[['LUNG_CANCER']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train.shape
# Out:
# (278, 13)

# %%
x_test.shape
# Out:
# (31, 13)

# %%
y_train.shape
# Out:
# (278, 1)

# %%
y_test.shape
# Out:
# (31, 1)

# %%
from sklearn.metrics import accuracy_score
from sklearn import svm
clf=svm.SVC()
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.8064516129032258

# %%
from sklearn.metrics import accuracy_score
from sklearn import tree
clf1 = tree.DecisionTreeClassifier()
clf1.fit(x_train,y_train)
y_pred=clf1.predict(x_test)
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.9032258064516129

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier(n_estimators=10)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.9032258064516129

# %%
prediction =clf1.predict([[1,62,1,1,1,2,1.0,2.0,2,1.0,1.0,2,1	]])
print(prediction)
# Out:
# ['YES']
